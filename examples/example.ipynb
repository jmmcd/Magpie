# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
import time
from Magpie import MagpieRegressor
import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.max_colwidth', None)
X, y = load_diabetes(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
start = time.time()
mr = MagpieRegressor(maxevals=20000, init_prop=0.2, random_state=42)
mr.fit(X_train, y_train)
end = time.time()
print(mr.equations_[["size", "loss", "loss_validation", "equation"]])
print(f"Elapsed time: {end - start}")
print(f"The R^2 on test data of the eqn with lowest validation MSE: {mr.score(X_test, y_test):.2f}")
# Out:
#    size  loss  loss_validation  \
# 0     2  1.00             1.00
# 1     6  1.00             1.00
# 2    10  0.62             0.62
# 3    14  0.62             0.62
# 4    18  0.62             0.62
# 5    22  0.49             0.49
# 6    28  0.49             0.49
# 7    30  0.49             0.49
#
#                                                                                      equation
# 0                                                                                    152.1197
# 1                                                                          (X[2] - -152.1210)
# 2                                                            ((1013.1736 * X[2]) - -153.4351)
# 3                                                    (153.4349 + (X[2] * (1013.1780 + X[1])))
# 4                                            (X[8] + (X[8] + ((X[2] - -0.1516) * 1012.2216)))
# 5                                   (X[3] + ((X[2] + ((X[8] + 0.2366) * 0.9226)) * 703.7047))
# 6  (-1336.2182 - (-2754.4613 / (sqrt(sqrt(((-0.7710 * -0.7710) - X[8]))) * (2.1095 - X[2]))))
# 7             ((0.2142 + X[2]) * ((((4.0993 + X[1]) - X[5]) * (-0.2339 - X[8])) * -732.2184))
# Elapsed time: 42.593547105789185
# The R^2 on test data of the eqn with lowest validation MSE: 0.31
